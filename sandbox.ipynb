# %% [markdown]
# ### dataset

# %%
from data import SourceSeparationDataset, MidSideDataset, collate_fn
from model import BandSplitRNN, PLModel
from pathlib import Path
import IPython.display as ipd

# %%
train_dataset = MidSideDataset(
    file_dir = '../data/musdb18hq',
    txt_dir = './files/new',
    target = 'vocals',
    preload_dataset = False,
    is_mono = False,
    is_training = True,
    sr = 44100,
    silent_prob = 0.1,
    mix_prob = 0.1,
    mix_tgt_too = False,
    side_stereo = False
)
# Out:
# 100%|██████████| 4288/4288 [00:00<00:00, 60152.30it/s]

# %%
train_dataset[0][0].shape
# Out:
# torch.Size([2, 264600])

# %%
ipd.Audio(train_dataset[0][1][0], rate=44100)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
